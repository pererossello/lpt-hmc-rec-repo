# %%
import os
import sys
import importlib
from functools import partial

import h5py
import numpy as np
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt

sys.path.append('../../../')
import forward_model
importlib.reload(forward_model)
from forward_model.lpt import get_forward_lpt
from forward_model.bias import get_forward_bias
from forward_model.main import get_forward_model
from forward_model.plot_utils import plot_cubes
from forward_model.ics import get_delta
from forward_model.utils import compute_or_load_pow_spec, compute_or_load_D1_D2

# %%
N, L, Z_I, Z_F = 64, 400, 99, 0
N_TR = 1e6

# Make ICS
SEED_INT_REF = 1
key_ref = jax.random.PRNGKey(SEED_INT_REF)
IC_METHOD = "FSK_U"
SHAPE = (N,)*3
u_ref = jax.random.normal(key_ref, shape=SHAPE)


# forward_model
LPT_METHOD = 'ALPT'
R_S = 1

MUSCLE=True
MUSCLE_ITERS='ONE'
SC_CORRECTION=True


BIAS_MODEL = "POWER_LAW"
ALPHA = 1.5
BIAS_PARAMS = {"ALPHA": ALPHA}

# BIAS_MODEL = 'HIERARCHICAL_POWER_LAW'
# key_ = jax.random.PRNGKey(1)
# alph_min, alph_max = 1, 2
# ALPHAS = jax.random.uniform(key_, (16,))*(alph_max-alph_min)+alph_min
# BIAS_PARAMS = {"ALPHA": ALPHAS, "LAMBDA_TH": 0.05}

argdic = {
    "N": N,
    "L": L,
    "Z_I": Z_I,
    "Z_F": Z_F,
    "LPT_METHOD": LPT_METHOD,
    "PM_METHOD": "CIC",
    "INPUT_ARG": IC_METHOD,
    "MUSCLE": MUSCLE,
    "MUSCLE_ITERS": MUSCLE_ITERS,
    "SC_CORRECTION": SC_CORRECTION,
    "BIAS_MODEL": BIAS_MODEL,
    "BIAS_PARAMS": BIAS_PARAMS,
    "N_TR": N_TR,
    "SAMPLE": 1,
}

get_tracers_poisson = get_forward_model(argdic)
argdic['SAMPLE'] = False
get_tracers_mean = get_forward_model(argdic)

n_tr_ref = get_tracers_poisson(u_ref)
axis, idx, width = 2, N // 2, 1
fig, ax = plot_cubes(
    [n_tr_ref], cmap="gnuplot2", vlim=(0, 10), axis=axis, width=width, idx=idx
)

# %%
epsilon = 1e-10
def nll(q):
    n_tr = get_tracers_mean(q)
    n_tr = jnp.where(n_tr == 0.0, epsilon, n_tr)
    nll = -jnp.sum(n_tr_ref * jnp.log(n_tr))
    return nll
nll = jax.jit(nll)
grad_nll = jax.grad(nll)
grad_nll = jax.jit(grad_nll)

# %%
SEED_INT = 62
key = jax.random.PRNGKey(SEED_INT)
u = jax.random.normal(key, shape=SHAPE)

pow_spec = compute_or_load_pow_spec(N, L, Z_I)
D1, D2 = compute_or_load_D1_D2(Z_I, Z_F)
delta_in = get_delta(u, N, L, IC_METHOD, pow_spec, return_hat=False)
delta_in = delta_in * D1

eps = 1e-5
bool_around = (delta_in<1.5+eps) & (delta_in>1.5-eps) 
frac_zeros_delta_in = jnp.sum(bool_around)/N**3
print('frac zeros delta in:', frac_zeros_delta_in)


n_tr = get_tracers_mean(u)
nll_val = nll(u)
grad_nll_vals = grad_nll(u)

print("nll:", nll_val)

axis, idx, width = 2, N // 4, 1
cmaps =  ["gnuplot2"] * 2 + ["seismic_r"]
vlims = [(0,10)]*2+[1e2]

fig, ax = plot_cubes(
    [n_tr_ref, n_tr, grad_nll_vals],
    cmap=cmaps,
    vlim=vlims,
    axis=axis,
    width=width,
    idx=idx,
)

gnll_has_nans = jnp.isnan(grad_nll_vals).any()
print('nans in gnll?', gnll_has_nans)

max_gnll = jnp.max(grad_nll_vals)
min_gnll = jnp.min(grad_nll_vals)
print('max_gnll', max_gnll)
print('max_gnll', min_gnll)

max_n_tr = jnp.max(n_tr)
min_n_tr = jnp.min(n_tr)
print('max_gnll', max_n_tr)
print('max_gnll', min_n_tr)
# Out:
# frac zeros delta in: 1.5258789e-05
# nll: -832284.5
# nans in gnll? False
# max_gnll 276.76706
# max_gnll -347.76074
# max_gnll 190.97423
# max_gnll 0.0

# %%
i = 0
gnll_has_nans = False
while gnll_has_nans == False:
    key = jax.random.PRNGKey(i)
    u = jax.random.normal(key, shape=SHAPE)

    n_tr = get_tracers_mean(u)
    nll_val = nll(u)
    grad_nll_vals = grad_nll(u)
    print(f'{i:03d}', end='\r')
    
    gnll_has_nans = jnp.isnan(grad_nll_vals).any()
    
    i+=1
# Out:
# 1796
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 7
#       4 key = jax.random.PRNGKey(i)
#       5 u = jax.random.normal(key, shape=SHAPE)
# ----> 7 n_tr = get_tracers_mean(u)
#       8 nll_val = nll(u)
#       9 grad_nll_vals = grad_nll(u)
#
# File ~/Documents/tfm/code_v2/lpt-hmc-rec-repo-master/forward_model/tests/forward_mod/../../../forward_model/main.py:30, in get_forward_model.<locals>.<lambda>(x)
#      27 forward_bias = get_forward_bias(**bias_args)
#      29 # Construct the forward model
# ---> 30 forward_model = lambda x: forward_bias(forward_lpt(x))
#      32 return forward_model
#
# File ~/Documents/tfm/code_v2/lpt-hmc-rec-repo-master/forward_model/tests/forward_mod/../../../forward_model/lpt.py:173, in forward_alpt(x, N, L, D1, D2, INPUT_ARG, pm_func, pow_spec, R_S, MUSCLE, MUSCLE_ITERS, SC_CORRECTION, PARTICLE_RIDGE, K_TH_PR, D_PR)
#     170 delta_in_hat = get_delta(x, N, L, INPUT_ARG, pow_spec, return_hat=True)
#     171 k_sq = jnp.square(get_k(N, L))
# --> 173 psi_x_hat, psi_y_hat, psi_z_hat = get_psi_alpt(
#     174     delta_in_hat,
#     175     D1,
#     176     D2,
#     177     k_sq,
#     178     N,
#     179     L,
#     180     R_S,
#     181     MUSCLE,
#     182     MUSCLE_ITERS,
#     183     SC_CORRECTION,
#     184 )
#     186 delta = from_psi_to_delta(
#     187     psi_x_hat, psi_y_hat, psi_z_hat, N, L, pm_func, psi_has_hat=True
#     188 )
#     190 if PARTICLE_RIDGE:
#
# File ~/Documents/tfm/code_v2/lpt-hmc-rec-repo-master/forward_model/tests/forward_mod/../../../forward_model/lpt_displacements.py:213, in get_psi_alpt(delta_in, D1, D2, k_sq, N, L, R_S, MUSCLE, MUSCLE_ITERS, SC_CORRECTION)
#     210 one_over_k_sq = jnp.where(k_sq > 0, 1 / k_sq, 0.0)
#     211 phi1 = -delta_in * one_over_k_sq
# --> 213 psi_lpt2_x, psi_lpt2_y, psi_lpt2_z = get_psi_lpt2(
#     214     phi1,
#     215     D1,
#     216     D2,
#     217     one_over_k_sq,
#     218     N,
#     219     L,
#     220 )
#     221 del phi1
#     223 delta_in = my_ifft(delta_in, L)
#
# File ~/Documents/tfm/code_v2/lpt-hmc-rec-repo-master/forward_model/tests/forward_mod/../../../forward_model/lpt_displacements.py:90, in get_psi_lpt2(phi1, D1, D2, one_over_k_sq, N, L)
#      85 """
#      86 Compute displacement field up to second order
#      87 """
#      89 psi1_x, psi1_y, psi1_z = get_psi_lpt1(phi1, N, L)
# ---> 90 psi2_x, psi2_y, psi2_z = get_psi_o2(psi1_x, psi1_y, psi1_z, one_over_k_sq, N, L)
#      92 psi_x = D1 * psi1_x + D2 * psi2_x
#      93 psi_y = D1 * psi1_y + D2 * psi2_y
#
# File ~/Documents/tfm/code_v2/lpt-hmc-rec-repo-master/forward_model/tests/forward_mod/../../../forward_model/lpt_displacements.py:63, in get_psi_o2(psi1_x, psi1_y, psi1_z, one_over_k_sq, N, L)
#      61 phi1_dxz = 1j * k_1D_r[None, None, :] * (-psi1_x)
#      62 phi1_dxz = my_ifft(phi1_dxz, L)
# ---> 63 arr2 = phi1_dxx * phi1_dzz - jnp.square(phi1_dxz)
#      64 del phi1_dxx, phi1_dxz
#      66 phi1_dyz = 1j * k_1D_r[None, None, :] * (-psi1_y)
#
# KeyboardInterrupt:

# %%
lpt = get_forward_lpt(
    N=N,
    L=L,
    Z_I=Z_I,
    Z_F=Z_F,
    LPT_METHOD=LPT_METHOD,
    PM_METHOD=argdic['PM_METHOD'], 
    INPUT_ARG=argdic['INPUT_ARG'], 
    MUSCLE=argdic['MUSCLE'],
    MUSCLE_ITERS=argdic['MUSCLE_ITERS'],
    SC_CORRECTION=argdic['SC_CORRECTION'],
)

delta_fin = lpt(u)

axis, idx, width = 2, N // 2, 1
fig, ax = plot_cubes(
    [delta_fin],
    cmap='gnuplot',
    vlim=(-1, 10),
    axis=axis,
    width=width,
    idx=idx,
)

max_delta_fin = jnp.max(delta_fin)
min_delta_fin = jnp.min(delta_fin)
print('max_gnll', max_delta_fin)
print('max_gnll', min_delta_fin)
# Out:
# max_gnll 49.99274
# max_gnll -1.0

# %%
def nll(q):
    n_tr = lpt(q)
    #n_tr = jnp.where(n_tr == 0.0, epsilon, n_tr)
    #nll = -jnp.sum(n_tr_ref * jnp.log(n_tr))
    nll = jnp.sum(n_tr)
    return nll
nll = jax.jit(nll)
grad_nll = jax.grad(nll)
grad_nll = jax.jit(grad_nll)

SEED_INT = 62
key = jax.random.PRNGKey(SEED_INT)
u = jax.random.normal(key, shape=SHAPE)

grad_nll_vals = grad_nll(u)

print('nll', nll(u))
gnll_has_nans = jnp.isnan(grad_nll_vals).any()
print('nans in gnll?', gnll_has_nans)

max_gnll = jnp.max(grad_nll_vals)
min_gnll = jnp.min(grad_nll_vals)
print('max_gnll', max_gnll)
print('max_gnll', min_gnll)
# Out:
# nll -0.0009765625
# nans in gnll? True
# max_gnll nan
# max_gnll nan

# %%
def nlp(q):
    return 0.5 * jnp.sum(jnp.abs(q) ** 2)

def kinetic(p):
    return 0.5 * jnp.sum(jnp.abs(p) ** 2)

def sample_momenta(key):
    p = jax.random.normal(key, SHAPE)
    return p

potential = lambda q: nlp(q) + nll(q)
potential = jax.jit(potential)
grad_potential = jax.grad(potential)
grad_potential = jax.jit(grad_potential)

kinetic = jax.jit(kinetic)
grad_kinetic = jax.grad(kinetic)
grad_kinetic = jax.jit(grad_kinetic)

hamiltonian = lambda q, p: potential(q) + kinetic(p)
hamiltonian = jax.jit(hamiltonian)


LF_STEP = 1e-4
def leapfrog_step(q, p):
    p_half_step = p - 0.5 * LF_STEP * grad_potential(q)
    q_new = q + LF_STEP * grad_kinetic(p_half_step)
    p_new = p_half_step - 0.5 * LF_STEP * grad_potential(q_new)
    return q_new, p_new

# %%
seed_p = 5
key_p = jax.random.PRNGKey(seed_p)
p = sample_momenta(key_p)

q_new, p_new = leapfrog_step(u, p)

q_has_nans = jnp.isnan(q_new).any()
print('nans in q_new?', q_has_nans)

p_has_nans = jnp.isnan(p_new).any()
print('nans in p_new?', p_has_nans)
# Out:
# nans in q_new? False
# nans in p_new? False

# %%
H_i = hamiltonian(u, p) 
H_f = hamiltonian(q_new, p_new)
delta_H = H_f - H_i
alpha = jnp.exp(-delta_H)

print(H_i)
print(H_f)
print(alpha)
# Out:
# 3704460.8
# 3704453.5
# 1408.1049

# %%
fs, rat = 5, 1.5
fig, ax = plt.subplots(1, 1, figsize=(fs*rat, fs))

max_gnll = jnp.max(grad_nll_vals)
min_gnll = jnp.min(grad_nll_vals)

print('max_gnll', max_gnll)
print('max_gnll', min_gnll)

abs_max_gnll = max([jnp.abs(min_gnll), jnp.abs(max_gnll)])

M=100
bin_edges = jnp.linspace(-abs_max_gnll, abs_max_gnll, M)

hist, edges = jnp.histogram(grad_nll_vals, bins=bin_edges)

ax.plot(edges[:-1], hist)

ax.set_yscale('log')
# Out:
# max_gnll 3045.958
# max_gnll -2427.198

# %%
def get_psi_sc_diff(self):

    delta_x = self.DeltaIn.get_ifft().real
    threshold = 3 / (2 * self.D1)
    transition_width = 0.01
    smooth_factor = jax.nn.sigmoid((threshold - delta_x) / transition_width)
    smooth_value = jnp.log1p(jnp.exp(1 - 2 / 3 * self.D1 * delta_x))
    phi_sc = my_fft(smooth_factor * jnp.sqrt(smooth_value), L=self.L)
    del smooth_factor, smooth_value

    A_hat = Cube(-3.0 * (1.0 - phi_sc), L=self.L, has_hat=True)
    del phi_sc

    PhiSC = Cube(
        A_hat.get_inverse_laplacian(return_hat=True), L=self.L, has_hat=True
    )

    psi = PhiSC.get_gradient(method=self.gradient_method, return_hat=False)
    
    return psi
